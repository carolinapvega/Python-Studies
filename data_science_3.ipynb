# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/carolinavega/Documents/Alura/Python-Studies/Python-Studies-1/HR-Employee-Attrition 3.csv')

# %%
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df_v1=df.drop(columns=['DistanceFromHome', "RelationshipSatisfaction", "StockOptionLevel", "TrainingTimesLastYear","WorkLifeBalance","YearsWithCurrManager", "EnvironmentSatisfaction", "NumCompaniesWorked", "Over18", "OverTime", "PercentSalaryHike","PerformanceRating", "TotalWorkingYears","YearsInCurrentRole"])

# %%
print(df_v1.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'StandardHours', 'YearsAtCompany', 'YearsSinceLastPromotion'],
#       dtype='object')

# %%
df_v1.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    Education EducationField  EmployeeCount  EmployeeNumber  Gender  ...  \
# 0          2  Life Sciences              1               1  Female  ...
# 1          1  Life Sciences              1               2    Male  ...
# 2          2          Other              1               4    Male  ...
# 3          4  Life Sciences              1               5  Female  ...
# 4          1        Medical              1               7    Male  ...
#
#    JobLevel                JobRole  JobSatisfaction MaritalStatus  \
# ...

# %%
df_v1['count']=''

# %%
aggregations = {
    
    'DailyRate': 'mean',
    'YearsAtCompany':'mean',
    'Age':'mean',
    'count': 'size'
    
}

# %%
df_v1 = df_v1.groupby(['Gender', 'JobLevel']).agg(aggregations).reset_index()

# %%
df_v1.head(50)
# Out:
#    Gender  JobLevel   DailyRate  YearsAtCompany        Age  count
# 0  Female         1  815.804020        4.040201  32.572864    199
# 1  Female         2  781.995455        6.800000  36.990909    220
# 2  Female         3  825.053191       10.861702  39.840426     94
# 3  Female         4  816.078431       11.764706  47.294118     51
# 4  Female         5  904.416667       13.791667  48.875000     24
# 5    Male         1  796.933140        3.869186  32.497093    344
# 6    Male         2  802.162420        6.719745  36.324841    314
# 7    Male         3  833.330645        8.258065  40.274194    124
# 8    Male         4  735.854545       15.854545  47.763636     55
# 9    Male         5  768.000000       15.844444  47.155556     45
